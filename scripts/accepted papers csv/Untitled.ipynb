# %%
import pandas as pd
import numpy as np

# %%
all_papers = pd.read_csv('all_papers.csv')
all_papers['title'] = all_papers['title'].astype(str)
accepted_papers = pd.read_excel('accepted.xlsx',  header=None)

# %%
accepted_papers.columns = ['paper_id', 'oral_pos', 'paper_type', 'track', 'title', 'abstract', 'authors' ]

# %%
accepted_papers['paper_id'] = accepted_papers['paper_id'].astype(str)

# %%
all_papers['paper_id'] = all_papers.pdf_url.str.split('.').str[-1]

# %%
all_papers.shape
# Out:
# (781, 10)

# %%
accepted_papers.shape
# Out:
# (326, 7)

# %%
combined_accepted = all_papers.merge(accepted_papers, how='inner', on='paper_id')

# %%
combined_accepted
# Out:
#            UID                                            title_x  \
# 0    main.1004  AnswerFact: Fact Checking in Product Question ...
# 1    main.1022  Context-Aware Answer Extraction in Question An...
# 2    main.1032  MultiCQA: Zero-Shot Transfer of Self-Supervise...
# 3     main.106  The role of context in neural pitch accent det...
# 4    main.1061  Alignment-free Cross-lingual Semantic Role Lab...
# ..         ...                                                ...
# 149   main.955  Discourse Self-Attention for Discourse Element...
# 150    main.96  Event Extraction by Answering (Almost) Natural...
# 151   main.983  Enhancing Aspect Term Extraction with Soft Pro...
# 152   main.995  Sub-Instruction Aware Vision-and-Language Navi...
# 153   main.999  Profile Consistency Identification for Open-do...
#
#                                              authors_x  \
# 0              Wenxuan Zhang|Yang Deng|Jing Ma|Wai Lam
# 1        Yeon Seonwoo|Ji-Hoon Kim|Jung-Woo Ha|Alice Oh
# 2         Andreas Rücklé|Jonas Pfeiffer|Iryna Gurevych
# 3     Elizabeth Nielsen|Mark Steedman|Sharon Goldwater
# 4                               Rui Cai|Mirella Lapata
# ..                                                 ...
# 149  Wei Song|Ziyao Song|Ruiji Fu|Lizhen Liu|Miaomi...
# 150                             Xinya Du|Claire Cardie
# 151                            Zhuang Chen|Tieyun Qian
# 152  Yicong Hong|Cristian Rodriguez|Qi Wu|Stephen G...
# 153  Haoyu Song|Yan Wang|Wei-Nan Zhang|Zhengyu Zhao...
#
#                                             abstract_x  \
# 0    Product-related question answering platforms n...
# 1    Extractive QA models have shown very promising...
# 2    We study the zero-shot transfer capabilities o...
# 3    Prosody is a rich information source in natura...
# 4    Cross-lingual semantic role labeling (SRL) aim...
# ..                                                 ...
# 149  This paper proposes to adapt self-attention to...
# 150  The problem of event extraction requires detec...
# 151  Aspect term extraction (ATE) aims to extract a...
# 152  Vision-and-language navigation requires an age...
# 153  Maintaining a consistent attribute profile is ...
#
#                                               keywords  \
# 0    online shopping|evidence-based tasks|answer pr...
# 1    context prediction|context task|reading compre...
# 2    answer tasks|zero-shot transfer|text models|se...
# 3    pitch detection|cnn-based model|phenomena|cont...
# 4    cross-lingual labeling|predicting roles|srl|ma...
# ..                                                 ...
# 149  self-attention|structural encodings|inter-sent...
# 150  event extraction|entity recognition|error prop...
# 151       aspect extraction|ate|neural taggers|taggers
# 152  vision-and-language navigation|navigation|agen...
# 153  attribute consistency|profile identification|d...
#
#                                                track_x paper_type_x  \
# 0                                   Question Answering         Long
# 1                                   Question Answering         Long
# 2                                     NLP Applications         Long
# 3                             Speech and Multimodality        Short
# 4    Semantics: Sentence-level Semantics, Textual I...         Long
# ..                                                 ...          ...
# 149                           Discourse and Pragmatics         Long
# 150                             Information Extraction         Long
# 151                             Information Extraction         Long
# 152  Language Grounding to Vision, Robotics and Beyond         Long
# 153                     Dialog and Interactive Systems         Long
#
#                                                pdf_url  presentation_id  \
# 0    https://www.aclweb.org/anthology/2020.emnlp-ma...              NaN
# 1    https://www.aclweb.org/anthology/2020.emnlp-ma...       38938829.0
# 2    https://www.aclweb.org/anthology/2020.emnlp-ma...       38938833.0
# 3    https://www.aclweb.org/anthology/2020.emnlp-ma...       38938650.0
# 4    https://www.aclweb.org/anthology/2020.emnlp-ma...       38938837.0
# ..                                                 ...              ...
# 149  https://www.aclweb.org/anthology/2020.emnlp-ma...       38938811.0
# 150  https://www.aclweb.org/anthology/2020.emnlp-ma...       38938649.0
# 151  https://www.aclweb.org/anthology/2020.emnlp-ma...       38938818.0
# 152  https://www.aclweb.org/anthology/2020.emnlp-ma...       38938820.0
# 153  https://www.aclweb.org/anthology/2020.emnlp-ma...       38938821.0
#
#     paper_id       oral_pos paper_type_y  \
# 0        188  Accept-Poster   Long Paper
# 1        189  Accept-Poster  Short Paper
# 2        194  Accept-Poster   Long Paper
# 3        642  Accept-Poster   Long Paper
# 4        319  Accept-Poster   Long Paper
# ..       ...            ...          ...
# 149      225    Accept-Oral   Long Paper
# 150       49  Accept-Poster   Long Paper
# 151      164    Accept-Oral   Long Paper
# 152      271    Accept-Oral   Long Paper
# 153      539  Accept-Poster  Short Paper
#
#                                                track_y  \
# 0                         Generation and Summarization
# 1    Information Retrieval, Search and Question Ans...
# 2                     Dialogue and Interactive Systems
# 3                         Semantics: Lexical Semantics
# 4               Information Extraction and Text Mining
# ..                                                 ...
# 149                           Discourse and Pragmatics
# 150    Interpretability and Analysis of Models for NLP
# 151  Sentiment Analysis, Stylistic Analysis, and Ar...
# 152  Information Retrieval, Search and Question Ans...
# 153                       Multidisciplinary and AC COI
#
#                                                title_y  \
# 0    Discourse Understanding and Factual Consistenc...
# 1    Knowledge Base Question Answering through Recu...
# 2    MONAH: Multi-Modal Narratives for Humans to an...
# 3    RelWalk - A Latent Variable Model Approach to ...
# 4    TrNews: Heterogeneous User-Interest Transfer L...
# ..                                                 ...
# 149  Joint Coreference Resolution and Character Lin...
# 150  Telling BERT's Full Story: from Local Attentio...
# 151   Exploiting Emojis for Abusive Language Detection
# 152          Query Generation for Multimodal Documents
# 153  Searching for Search Errors in Neural Morpholo...
#
#                                             abstract_y  \
# 0    We introduce a general framework for abstracti...
# 1    Knowledge Base Question Answering (KBQA) is th...
# 2    In conversational analyses, humans manually we...
# 3    Embedding entities and relations of a knowledg...
# 4    We investigate how to solve the cross-corpus n...
# ..                                                 ...
# 149  Character linking, the task of linking mention...
# 150  We take a deep look into the behaviour of self...
# 151  We propose to use abusive emojis, such as the ...
# 152  This paper studies the problem of generatingli...
# 153  Neural sequence-to-sequence models are current...
#
#                                              authors_y
# 0    Saadia Gabriel, Antoine Bosselut, Jeff Da, Ari...
# 1    Naganand yadati, Dayanidhi R S, Vaishnavi S, I...
# 2    Joshua Y. Kim, Kalina Yacef, Greyson Kim, Chun...
# 3    Danushka Bollegala, Huda Hakami, Yuichi Yoshid...
# 4                          Guangneng Hu and Qiang Yang
# ..                                                 ...
# 149  Jiaxin Bai, Hongming Zhang, Yangqiu Song and K...
# 150  Damian Pascual, Gino Brunner and Roger Wattenh...
# 151              Michael Wiegand and Josef Ruppenhofer
# 152  kyungho kim, Kyungjae Lee, Seung-won Hwang, Yo...
# 153  Martina Forster, Clara Meister and Ryan Cotterell
#
# [154 rows x 16 columns]

# %%
combined_accepted.shape
# Out:
# (154, 16)

# %%
all_papers
# Out:
#            UID                                              title  \
# 0    main.1004  AnswerFact: Fact Checking in Product Question ...
# 1    main.1006  Knowledge-Grounded Dialogue Generation with Pr...
# 2    main.1009  BiST: Bi-directional Spatio-Temporal Reasoning...
# 3    main.1010  A Knowledge-Aware Sequence-to-Tree Network for...
# 4    main.1011  Knowledge Association with Hyperbolic Knowledg...
# ..         ...                                                ...
# 776  TACL.2169                                     A* Beam Search
# 777  TACL.2221  Consistent Transcription and Translation of Sp...
# 778  TACL.2255  PERL: Pivot-based Domain Adaptation for Pre-tr...
# 779  TACL.2389  Improving Dialog Evaluation with a Multi-refer...
# 780  TACL.2411  Syntactic Structure Distillation Pretraining f...
#
#                                                authors  \
# 0              Wenxuan Zhang|Yang Deng|Jing Ma|Wai Lam
# 1    Xueliang Zhao|Wei Wu|Can Xu|Chongyang Tao|Dong...
# 2       Hung Le|Doyen Sahoo|Nancy Chen|Steven C.H. Hoi
# 3         Qinzhuo Wu|Qi Zhang|Jinlan Fu|Xuanjing Huang
# 4    Zequn Sun|Muhao Chen|Wei Hu|Chengming Wang|Jia...
# ..                                                 ...
# 776            Clara Meister|Ryan Cotterell|Tim Vieira
# 777  Matthias Sperber|Hendra Setiawan|Christian Gol...
# 778      Roi Reichart|Eyal Ben David|Carmel Rabinovitz
# 779  Ananya Sai|Akash Mohan Kumar|Siddhartha Arora|...
# 780  Adhiguna Kuncoro|Lingpeng Kong|Daniel Fried|Da...
#
#                                               abstract  \
# 0    Product-related question answering platforms n...
# 1    We study knowledge-grounded dialogue generatio...
# 2    Video-grounded dialogues are very challenging ...
# 3    With the advancements in natural language proc...
# 4    Capturing associations for knowledge graphs (K...
# ..                                                 ...
# 776  Decoding for many NLP tasks requires an effect...
# 777  The conventional paradigm in speech translatio...
# 778  Pivot-based neural representation models have ...
# 779  There is an increasing focus on model-based di...
# 780  Textual representation learners trained on lar...
#
#                                               keywords  \
# 0    online shopping|evidence-based tasks|answer pr...
# 1    knowledge-grounded generation|equipping|knowle...
# 2    video-grounded dialogues|high-resolution queri...
# 3    natural tasks|math solving|generation|knowledg...
# 4    capturing associations|entity alignment|entity...
# ..                                                 ...
# 776  nlp tasks|exact search|decoding|heuristic algo...
# 777  speech translation|jointly speech|joint task|s...
# 778  domain adaptation|nlp|sentiment setups|in-doma...
# 779  large pretraining|embedding metrics|n-gram met...
# 780  bert pretraining|structured tasks|natural unde...
#
#                                       track paper_type  \
# 0                        Question Answering       Long
# 1            Dialog and Interactive Systems       Long
# 2            Dialog and Interactive Systems       Long
# 3                          NLP Applications       Long
# 4                    Information Extraction       Long
# ..                                      ...        ...
# 776                     Language Generation       TACL
# 777                Speech and Multimodality       TACL
# 778                Machine Learning for NLP       TACL
# 779          Dialog and Interactive Systems       TACL
# 780  Syntax: Tagging, Chunking, and Parsing       TACL
#
#                                                pdf_url  presentation_id  \
# 0    https://www.aclweb.org/anthology/2020.emnlp-ma...              NaN
# 1    https://www.aclweb.org/anthology/2020.emnlp-ma...       38938823.0
# 2    https://www.aclweb.org/anthology/2020.emnlp-ma...       38938824.0
# 3    https://www.aclweb.org/anthology/2020.emnlp-ma...       38938825.0
# 4    https://www.aclweb.org/anthology/2020.emnlp-ma...       38938826.0
# ..                                                 ...              ...
# 776                                                NaN       38939414.0
# 777                                                NaN       38939415.0
# 778                                                NaN       38939416.0
# 779                                                NaN       38939417.0
# 780                                                NaN       38939418.0
#
#     paper_id
# 0        188
# 1        272
# 2        145
# 3        579
# 4        460
# ..       ...
# 776      NaN
# 777      NaN
# 778      NaN
# 779      NaN
# 780      NaN
#
# [781 rows x 10 columns]

# %%
accepted_papers
# Out:
#     paper_id       oral_pos  paper_type  \
# 0        163  Accept-Poster  Long Paper
# 1        182  Accept-Poster  Long Paper
# 2        375  Accept-Poster  Long Paper
# 3        500  Accept-Poster  Long Paper
# 4        789  Accept-Poster  Long Paper
# ..       ...            ...         ...
# 321      330  Accept-Poster  Long Paper
# 322      683    Accept-Oral  Long Paper
# 323      898  Accept-Poster  Long Paper
# 324     1109  Accept-Poster  Long Paper
# 325     1283  Accept-Poster  Long Paper
#
#                                              track  \
# 0    Computational Social Science and Social Media
# 1    Computational Social Science and Social Media
# 2    Computational Social Science and Social Media
# 3    Computational Social Science and Social Media
# 4    Computational Social Science and Social Media
# ..                                             ...
# 321         Syntax: Tagging, Chunking, and Parsing
# 322         Syntax: Tagging, Chunking, and Parsing
# 323         Syntax: Tagging, Chunking, and Parsing
# 324         Syntax: Tagging, Chunking, and Parsing
# 325         Syntax: Tagging, Chunking, and Parsing
#
#                                                  title  \
# 0    Implicitly Abusive Comparisons -- A New Datase...
# 1    Semantic Oppositeness Assisted Deep Contextual...
# 2    Hierarchical Multi-head Attentive Network for ...
# 3    An Expert Annotated Dataset for the Detection ...
# 4    Us vs. Them: A Dataset of Populist Attitudes, ...
# ..                                                 ...
# 321  Coordinate Constructions in English Enhanced U...
# 322  Dependency parsing with structure preserving e...
# 323  Calculating the optimal step of arc-eager pars...
# 324  PPT: Parsimonious Parser Transfer for Unsuperv...
# 325  Reanalyzing the Most Probable Sentence Problem...
#
#                                               abstract  \
# 0    We examine the task of detecting implicitly ab...
# 1    Social networks face a major challenge in the ...
# 2    The widespread of fake news and misinformation...
# 3    Online misogyny is a pernicious social problem...
# 4    Computational modelling of political discourse...
# ..                                                 ...
# 321  In this paper, we address the representation o...
# 322  Modern neural approaches to dependency parsing...
# 323  It is shown that the optimal next step of an a...
# 324  Cross-lingual transfer is a leading technique ...
# 325  When working with problems in natural language...
#
#                                                authors
# 0    Michael Wiegand, Maja Geulig and Josef Ruppenh...
# 1                      Nisansa de Silva and Dejing Dou
# 2                             Nguyen Vo and Kyumin Lee
# 3    Ella Guest, Bertie Vidgen, Alexandros Mittos, ...
# 4    Pere-Lluís Huguet Cabot, David Abadi, Agneta F...
# ..                                                 ...
# 321  Stefan Grünewald, Prisca Piccirilli and Annema...
# 322  Ákos Kádár, Lan Xiao, Mete Kemertas, Federico ...
# 323                                  Mark-Jan Nederhof
# 324  Kemal Kurniawan, Lea Frermann, Philip Schulz a...
# 325                       Eric Corlett and Gerald Penn
#
# [326 rows x 7 columns]
